# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/happiness_rank.csv")

# %%
df
# Out:
#                       Country  Rank  Score  Support      GDP   Health  \
# 0                 Switzerland     1  7.587  1.39651  1.34951  0.94143
# 1                     Iceland     2  7.561  1.30232  1.40223  0.94784
# 2                     Denmark     3  7.527  1.32548  1.36058  0.87464
# 3                      Norway     4  7.522  1.45900  1.33095  0.88521
# 4                      Canada     5  7.427  1.32629  1.32261  0.90563
# ..                        ...   ...    ...      ...      ...      ...
# 772                    Rwanda   152  3.334  0.71100  0.35900  0.61400
# 773                  Tanzania   153  3.231  0.88500  0.47600  0.49900
# 774               Afghanistan   154  3.203  0.51700  0.35000  0.36100
# 775  Central African Republic   155  3.083  0.00000  0.02600  0.10500
# 776               South Sudan   156  2.853  0.57500  0.30600  0.29500
#
#      Freedom  Generosity  Corruption  Year target  target_n
# 0    0.66557     0.41978     0.29678  2015    Top         4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     777 non-null    object
#  1   Rank        777 non-null    int64
#  2   Score       777 non-null    float64
#  3   Support     777 non-null    float64
#  4   GDP         777 non-null    float64
#  5   Health      777 non-null    float64
#  6   Freedom     777 non-null    float64
#  7   Generosity  777 non-null    float64
#  8   Corruption  777 non-null    float64
#  9   Year        777 non-null    int64
#  10  target      777 non-null    object
#  11  target_n    777 non-null    int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 73.0+ KB

# %%
# df["Score"].plot(title="Score - Line Plot")
# plt.show()
# df["GDP"].plot(title="GDP - Line Plot")
# plt.show()
# df["Health"].plot(title="Health - Line Plot")
# plt.show()
# df["Freedom"].plot(title="Freedom - Line Plot")
# plt.show()
# df["Generosity"].plot(title="Generosity - Line Plot")
# plt.show()
# df["Corruption"].plot(title="Corruption - Line Plot")
# plt.show()

# %%
# df["Score"].plot.bar(title="Score - Bar Plot")
# plt.show()
# df["GDP"].plot.bar(title="GDP - Bar Plot")
# plt.show()
# df["Health"].plot.bar(title="Health - Bar Plot")
# plt.show()
# df["Freedom"].plot.bar(title="Freedom - Bar Plot")
# plt.show()
# df["Generosity"].plot.bar(title="Generosity - Bar Plot")
# plt.show()
# df["Corruption"].plot.bar(title="Corruption - Bar Plot")
# plt.show()

# %%
# df["Score"].plot.barh(title="Score - Horizontal Bar Plot")
# plt.show()
# df["GDP"].plot.barh(title="GDP - Horizontal Bar Plot")
# plt.show()
# df["Health"].plot.barh(title="Health - Horizontal Bar Plot")
# plt.show()
# df["Freedom"].plot.barh(title="Freedom - Horizontal Bar Plot")
# plt.show()
# df["Generosity"].plot.barh(title="Generosity - Horizontal Bar Plot")
# plt.show()
# df["Corruption"].plot.barh(title="Corruption - Horizontal Bar Plot")
# plt.show()

# %%
df["Score"].plot.hist(title="Score - Histogram", bins=15, alpha=0.91)
plt.show()

# %%
df.plot.box()
plt.show()

# %%
df["Score"].plot.box(title="Score - Box Plot")
plt.show()
df["GDP"].plot.box(title="GDP - Box Plot")
plt.show()
df["Health"].plot.box(title="Health - Box Plot")
plt.show()
df["Freedom"].plot.box(title="Freedom - Box Plot")
plt.show()
df["Generosity"].plot.box(title="Generosity - Box Plot")
plt.show()
df["Corruption"].plot.box(title="Corruption - Box Plot")
plt.show()

# %%
df["Score"].plot.box(title="Score - Box Plot")
plt.show()
df["GDP"].plot.box(title="GDP - Box Plot")
plt.show()
df["Health"].plot.box(title="Health - Box Plot")
plt.show()
df["Freedom"].plot.box(title="Freedom - Box Plot")
plt.show()
df["Generosity"].plot.box(title="Generosity - Box Plot")
plt.show()
df["Corruption"].plot.box(title="Corruption - Box Plot")
plt.show()

# %%
df["Score"].plot.kde(title="Score - KDE Plot")
plt.show()
df["GDP"].plot.kde(title="GDP - KDE Plot")
plt.show()
df["Health"].plot.kde(title="Health - KDE Plot")
plt.show()
df["Freedom"].plot.kde(title="Freedom - KDE Plot")
plt.show()
df["Generosity"].plot.kde(title="Generosity - KDE Plot")
plt.show()
df["Corruption"].plot.kde(title="Corruption - KDE Plot")
plt.show()

# %%
df["Score"].plot.area(title="Score - Area Plot", alpha=0.4)
plt.show()
df["GDP"].plot.area(title="GDP - Area Plot", alpha=0.4)
plt.show()
df["Health"].plot.area(title="Health - Area Plot", alpha=0.4)
plt.show()
df["Freedom"].plot.area(title="Freedom - Area Plot", alpha=0.4)
plt.show()
df["Generosity"].plot.area(title="Generosity - Area Plot", alpha=0.4)
plt.show()
df["Corruption"].plot.area(title="Corruption - Area Plot", alpha=0.4)
plt.show()

# %%
df["Score"].plot.pie(title="Score - Pie Plot", autopct="%1.1f%%")
plt.show()
df["GDP"].plot.pie(title="GDP - Pie Plot", autopct="%1.1f%%")
plt.show()
df["Health"].plot.pie(title="Health - Pie Plot", autopct="%1.1f%%")
plt.show()
df["Freedom"].plot.pie(title="Freedom - Pie Plot", autopct="%1.1f%%")
plt.show()
df["Generosity"].plot.pie(title="Generosity - Pie Plot", autopct="%1.1f%%")
plt.show()
df["Corruption"].plot.pie(title="Corruption - Pie Plot", autopct="%1.1f%%")
plt.show()

# %%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     777 non-null    object
#  1   Rank        777 non-null    int64
#  2   Score       777 non-null    float64
#  3   Support     777 non-null    float64
#  4   GDP         777 non-null    float64
#  5   Health      777 non-null    float64
#  6   Freedom     777 non-null    float64
#  7   Generosity  777 non-null    float64
#  8   Corruption  777 non-null    float64
#  9   Year        777 non-null    int64
#  10  target      777 non-null    object
#  11  target_n    777 non-null    int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 73.0+ KB


# Function to plot all pandas DataFrame plots with customizations
def plot_dataframe(df):
    # Line plot
    df.plot(title="Line Plot", color=["r", "g", "b", "c", "m", "y", "k"])
    plt.show()

    # Bar plot
    df.plot.bar(title="Bar Plot", color=["r", "g", "b", "c", "m", "y", "k"])
    plt.show()

    # Horizontal bar plot
    df.plot.barh(title="Horizontal Bar Plot", color=["r", "g", "b", "c", "m", "y", "k"])
    plt.show()

    # Histogram
    df.plot.hist(title="Histogram", bins=15, alpha=0.7)
    plt.show()

    # Box plot
    df.plot.box(title="Box Plot")
    plt.show()

    # KDE (Kernel Density Estimate) plot
    df.plot.kde(title="KDE Plot")
    plt.show()

    # Area plot
    df.plot.area(title="Area Plot", alpha=0.4)
    plt.show()

    # Scatter plot
    df.plot.scatter(x="GDP", y="Score", title="Scatter Plot: GDP vs Score", color="r")
    plt.show()

    # Grouped bar plot using 'by' keyword
    df.groupby("target").mean().plot.bar(
        title="Grouped Bar Plot by Target", color=["r", "g", "b", "c", "m", "y", "k"]
    )
    plt.show()

    # Grouped horizontal bar plot using 'by' keyword
    df.groupby("target").mean().plot.barh(
        title="Grouped Horizontal Bar Plot by Target",
        color=["r", "g", "b", "c", "m", "y", "k"],
    )
    plt.show()


# Function to plot all pandas Series plots with customizations
def plot_series(series):
    # Line plot
    series.plot(title="Line Plot", color="r")
    plt.show()

    # Bar plot
    series.plot.bar(title="Bar Plot", color="r")
    plt.show()

    # Horizontal bar plot
    series.plot.barh(title="Horizontal Bar Plot", color="r")
    plt.show()

    # Histogram
    series.plot.hist(title="Histogram", bins=15, alpha=0.7, color="r")
    plt.show()

    # Box plot
    series.plot.box(title="Box Plot")
    plt.show()

    # KDE (Kernel Density Estimate) plot
    series.plot.kde(title="KDE Plot")
    plt.show()

    # Area plot
    series.plot.area(title="Area Plot", alpha=0.4)
    plt.show()

    # Pie plot
    series.plot.pie(title="Pie Plot", autopct="%1.1f%%")
    plt.show()


# Plot all DataFrame plots
plot_dataframe(df)

# Plot all Series plots (example using 'Score' column)
plot_series(df["Score"])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/introduction_to_data_analytics-jZTzfAo0-py3.10/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/.cache/pypoetry/virtualenvs/introduction_to_data_analytics-jZTzfAo0-py3.10/lib/python3.10/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...
