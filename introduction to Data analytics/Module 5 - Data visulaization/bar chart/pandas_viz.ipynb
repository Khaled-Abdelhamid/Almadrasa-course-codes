# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a list with 3 different categories
category = ["Group1"] * 30 + ["Group2"] * 50 + ["Group3"] * 20

# Store the data into a dataframe
df = pd.DataFrame({"category": category})
df
# Out:
#    category
# 0    Group1
# 1    Group1
# 2    Group1
# 3    Group1
# 4    Group1
# ..      ...
# 95   Group3
# 96   Group3
# 97   Group3
# 98   Group3
# 99   Group3
#
# [100 rows x 1 columns]

# %%
# Create the plot
values.plot(
    kind="bar",  # type of chart
    grid=True,  # Add a grid in the background
)
plt.show()

# %%
# Get the repartition of each category
values = df["category"].value_counts()

# Define colors to use
colors = ["#69b3a2", "#cb1dd1", "palegreen"]

# Create the plot as a horizontal bar plot
values.plot.barh(color=colors, grid=True)  # Use barh for a horizontal bar plot
# values.plot(kind="bar", color=colors, grid=True)  # Use barh for a horizontal bar plot
# plt.grid()
plt.show()

# %%
# Get the repartition of each category
values = df["category"].value_counts()
print(values)
# Define the desired order of categories
desired_order = ["Group1", "Group2", "Group3"]  # Change this order as needed
values = values.reindex(desired_order)  # Reindex the values in the desired order
print(values)
# Out:
# category
# Group2    50
# Group1    30
# Group3    20
# Name: count, dtype: int64
# category
# Group1    30
# Group2    50
# Group3    20
# Name: count, dtype: int64

# %%
# Define colors to use
colors = ["#69b3a2", "#cb1dd1", "palegreen"]

# Create the plot as a horizontal bar plot
ax = values.plot.bar(
    color=colors,
    grid=True,
)

# Add title and label
ax.set_title("Customized Barplot")
ax.set_xlabel("Numbers by category")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Product": [
        "Product A",
        "Product A",
        "Product A",
        "Product B",
        "Product B",
        "Product B",
    ],
    "Segment": [
        "Segment 1",
        "Segment 2",
        "Segment 3",
        "Segment 1",
        "Segment 2",
        "Segment 3",
    ],
    "Amount_sold": [100, 120, 120, 80, 160, 150],
}

df = pd.DataFrame(data)
df
# Out:
#      Product    Segment  Amount_sold
# 0  Product A  Segment 1          100
# 1  Product A  Segment 2          120
# 2  Product A  Segment 3          120
# 3  Product B  Segment 1           80
# 4  Product B  Segment 2          160
# 5  Product B  Segment 3          150

# %%
# Pivot the data to have 'Product' as columns and 'Segment' as the index
pivot_df = df.pivot(index="Segment", columns="Product", values="Amount_sold")
pivot_df
# Out:
# Product    Product A  Product B
# Segment
# Segment 1        100         80
# Segment 2        120        160
# Segment 3        120        150

# %%
# Create a grouped barplot
pivot_df.plot.bar(grid=True)

plt.show()

# %%
# Pivot the data to have 'Product' as columns and 'Segment' as the index
pivot_df = df.pivot(index="Product", columns="Segment", values="Amount_sold")
pivot_df
# Out:
# Segment    Segment 1  Segment 2  Segment 3
# Product
# Product A        100        120        120
# Product B         80        160        150

# %%
# Create a grouped barplot
colors = ["purple", "orange","blue"]
ax = pivot_df.plot.bar(grid=True, color=colors, figsize=(6, 6))

# Add legend
plt.legend(loc="upper left")

# Add title and label
ax.set_xlabel("Product")
ax.set_ylabel("Amount Sold")
ax.set_title("Sales by Segment and Product")

plt.show()
